# %%
import requests

link = 'https://fab35870-ba78-41e5-b46c-cc021fb9c067-00-1g4xtarlnbovr.janeway.replit.dev/total_luz'

requisicao = requests.get(link)

print('status da requisição:', requisicao.status_code)
retorno = requisicao.json()
print(link)
print(f'1o. Endpoint' ,requisicao.json())
# Out:
# status da requisição: 200
# https://fab35870-ba78-41e5-b46c-cc021fb9c067-00-1g4xtarlnbovr.janeway.replit.dev/total_luz
# 1o. Endpoint {'Gasto com a Luz': 9200}

# %%
link = 'https://fab35870-ba78-41e5-b46c-cc021fb9c067-00-1g4xtarlnbovr.janeway.replit.dev/total_mes'

requisicao = requests.get(link)

print('status da requisição:', requisicao.status_code)
retorno = requisicao.json()
print(link)
print(f'2o. Endpoint' ,requisicao.json())
# Out:
# status da requisição: 200
# https://fab35870-ba78-41e5-b46c-cc021fb9c067-00-1g4xtarlnbovr.janeway.replit.dev/total_mes
# 2o. Endpoint {'Gasto do Mês': 402960}
